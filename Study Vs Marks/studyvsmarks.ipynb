# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data.csv')

# %%
print(dataset)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
X = dataset.iloc[:, 0:-1].values
y = dataset.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred = y_pred.reshape(len(y_pred), 1)
y_test = y_test.reshape(len(y_test), 1)

# %%
print('[Actual       Predicted]')
print(np.concatenate((y_test, y_pred), 1))
# Out:
# [Actual       Predicted]
# [[95.         89.61314433]
#  [41.         46.49089521]
#  [20.         17.08936172]
#  [75.         85.69293986]
#  [86.         78.83258205]]

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressor.predict(X))
plt.title('Study Vs Marks')
plt.xlabel('Study in Hours')
plt.ylabel('Marks')
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y, regressor.predict(X))
# Out:
# 0.9529407623371005

# %%
#testing for new data
while(True):
    x = float(input('Study Hours: '))
    if(x == 0):
        break
    print(f'Study {x}hrs get {regressor.predict([[x]])[0]} marks')
# Out:
# Study 9.25hrs get 93.0433232356906 marks
